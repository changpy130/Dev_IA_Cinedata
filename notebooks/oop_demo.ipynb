# %% [markdown]
# ### Config

# %%
import pandas as pd
import sys
from pathlib import Path

project_root = Path.cwd().parent
sys.path.append(str(project_root))

# %% [markdown]
# ### TMDBExtractor model

# %%
from src.TMDBExtractor import TMDBExtractor

# %% [markdown]
# ### Popular movies

# %%
extractor = TMDBExtractor()
print(extractor.genre_mapping)

movies = extractor.get_popular_movies()

for movie in movies:
    print(f"{movie.id} {movie.title} ({movie.release_date})")
# Out:
# {28: 'Action', 12: 'Adventure', 16: 'Animation', 35: 'Comedy', 80: 'Crime', 99: 'Documentary', 18: 'Drama', 10751: 'Family', 14: 'Fantasy', 36: 'History', 27: 'Horror', 10402: 'Music', 9648: 'Mystery', 10749: 'Romance', 878: 'Science Fiction', 10770: 'TV Movie', 53: 'Thriller', 10752: 'War', 37: 'Western'}
# 969681 Spider-Man: Brand New Day (2026-07-29)
# 1423191 Resident Evil (2026-09-16)
# 1101383 The End of Oak Street (2026-08-12)
# 1204680 Coyote vs. Acme (2026-08-20)
# 1375646 Colony (2026-05-21)
# 1368337 The Odyssey (2026-07-15)
# 1294189 The Mongoose (2026-10-29)
# 1482547 Zip Wire (2026-08-31)
# 1285366 Shape of My Heart (2024-07-06)
# 1108427 Moana (2026-07-08)
# 1288445 Mutiny (2026-08-19)
# 1440098 Drawn Together (2026-09-09)
# 1084244 Toy Story 5 (2026-06-17)
# 1386315 The Runner (2026-09-03)
# 1339713 Obsession (2026-05-13)
# 1232569 Pinocchio: Unstrung (2026-07-22)
# 1315772 Minions & Monsters (2026-06-24)
# 1323244 Rage of Stars (2026-08-06)
# ...

# %% [markdown]
# ### Movie details

# %%
extractor.get_movie_details(1368337)
# Out:
# MoviewDetails(id=1368337, imdb_id='tt33764258', title='The Odyssey', origin_country=['GB', 'US'], original_title='The Odyssey', budget=250000000, revenue=1723918419, runtime=173, vote_average=8.016, tagline='Defy the gods.')

# %% [markdown]
# ### Credit

# %%
credit = extractor.get_movie_credits(1368337, crew_jobs=["Producer", "Writer"])
print(credit.cast)
print(credit.crew)
# Out:
# [Cast(id=1892, name='Matt Damon', character='Odysseus', profile_path='/aCvBXTAR9B1qRjIRzMBYhhbm1fR.jpg', known_for_department='Acting'), Cast(id=1136406, name='Tom Holland', character='Telemachus', profile_path='/5OK84Wn1bIEIThFKcVoaN087mLj.jpg', known_for_department='Acting'), Cast(id=1813, name='Anne Hathaway', character='Penelope', profile_path='/nbccV2pMoyLTCeg5DQip24Eq0Jp.jpg', known_for_department='Acting'), Cast(id=11288, name='Robert Pattinson', character='Antinous', profile_path='/3qZ09UE7lN6AtorfXFRYpEtSY93.jpg', known_for_department='Acting'), Cast(id=1227717, name='Himesh Patel', character='Eurylochus', profile_path='/icqsXLmU0FxBGTv63kkA0GcrecO.jpg', known_for_department='Acting')]
# ...
